# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

#Custom function to show open cv image on notebook.
def display_img(cvImg):
    cvImg = cv2.cvtColor(cvImg, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10,8))
    plt.imshow(cvImg)
    plt.axis('off')
    plt.show()

# %%
#Loading image using cv2
baseImg = cv2.imread('base_cccd.png')

#Declare image size, width height and chanel
baseH, baseW, baseC = baseImg.shape

display_img(baseImg)

# %% [markdown]
# # Detect cccd

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load mô hình YOLOv8 đã huấn luyện
model = YOLO('weights/detect_cccd_best.pt')

# Đọc ảnh
image_path = 'test.jpg'
image = cv2.imread(image_path)
img2 = None

# Detect object
results = model(image)

for result in results:
    for box in result.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Lấy tọa độ bounding box

        # Crop ảnh CCCD
        img2 = image[y1:y2, x1:x2]

        # Lưu ảnh đã crop
        cv2.imwrite("cccd_crop.jpg", image)

        # Hiển thị ảnh crop bằng Matplotlib
        plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
        plt.title("Cropped CCCD")
        plt.axis("off")
        plt.show()

# Lưu ảnh có bounding box
cv2.imwrite("output_detect.jpg", img2)
# Out:
# 0: 640x480 1 cccd, 92.0ms
# Speed: 2.5ms preprocess, 92.0ms inference, 99.2ms postprocess per image at shape (1, 3, 640, 480)
# True

# %% [markdown]
# # Preprocess image

# %%
#Init orb, keypoints detection on base Image
orb = cv2.ORB_create(1000)

kp, des = orb.detectAndCompute(baseImg, None)
imgKp = cv2.drawKeypoints(baseImg,kp, None)

display_img(imgKp)

# %%
PER_MATCH = 0.25

#Detect keypoint on img2
kp1, des1 = orb.detectAndCompute(img2, None)

#Init BF Matcher, find the matches points of two images
bf = cv2.BFMatcher(cv2.NORM_HAMMING)
matches = list(bf.match(des1, des))

#Select top 30% best matcher 
matches.sort(key=lambda x: x.distance)
best_matches = matches[:int(len(matches)*PER_MATCH)]

#Show match img  
imgMatch = cv2.drawMatches(img2, kp1, baseImg, kp, best_matches,None, flags=2)
display_img(imgMatch)

# %%
#Init source points and destination points for findHomography function.
srcPoints = np.float32([kp1[m.queryIdx].pt for m in best_matches]).reshape(-1,1,2)
dstPoints = np.float32([kp[m.trainIdx].pt for m in best_matches]).reshape(-1,1,2)


#Find Homography of two images
matrix_relationship, _ = cv2.findHomography(srcPoints, dstPoints,cv2.RANSAC, 5.0)

#Transform the image to have the same structure as the base image
img_final = cv2.warpPerspective(img2, matrix_relationship, (baseW, baseH))

display_img(img_final)

# %% [markdown]
# # Text detect

# %%
# prepare data

# Thư mục chứa ảnh đầu vào
input_folder = "data/Cloud của tôi [21-03-2025 21_17]"

# Thư mục chứa ảnh đầu ra (tạo nếu chưa có)
output_folder = "output_cccd"
os.makedirs(output_folder, exist_ok=True)

# Load mô hình YOLO đã huấn luyện
model = YOLO("weights/detect_cccd_best.pt")

# Lấy danh sách file ảnh trong thư mục input
image_files = [f for f in os.listdir(input_folder) if f.endswith((".jpg", ".png", ".jpeg"))]
print(image_files)
# Đếm số lượng ảnh đã lưu
count = 1

for image_name in image_files:
    image_path = os.path.join(input_folder, image_name)
    image = cv2.imread(image_path)
    if image is None:
        print(f"Lỗi khi đọc ảnh: {image_name}")
        continue

    # Detect CCCD
    results = model(image)

    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Lấy tọa độ bounding box

            # Cắt ảnh CCCD từ ảnh gốc
            cropped_img = image[y1:y2, x1:x2]

            # Lưu ảnh đã cắt vào thư mục output
            output_path = os.path.join(output_folder, f"cccd_{count}.jpg")
            cv2.imwrite(output_path, cropped_img)
            print(f"Lưu ảnh: {output_path}")
            count += 1  # Tăng số thứ tự ảnh
# Out:
# ['585f2b507332c36c9a2311.jpg', '834eae94f5f645a81ce721.jpg', '45efa2f0fa924acc138310.jpg', 'c19b25917df3cdad94e214.jpg', '2453db8280e030be69f122.jpg', 'fc2b8a46d224627a3b352.jpg', '6bd684fcdc9e6cc0358f17.jpg', '8fd004af5ccdec93b5dc6.jpg', '263079572135916bc8244.jpg', 'f8ad26937ef1ceaf97e020.jpg', '802a44ce1facaff2f6bd24.jpg', '56213149692bd975803a5.jpg', 'f13209135171e12fb86018.jpg', '56894cd914bba4e5fdaa1.jpg', 'e92126527e30ce6e972112.jpg', 'f2c63ca664c4d49a8dd53.jpg', '93d5a3d4fbb64be812a713.jpg', 'c794c3ef9b8d2bd3729c9.jpg', 'f23440161874a82af16519.jpg', 'e9f69eeec68c76d22f9d7.jpg', 'c71ff408ac6a1c34457b16.jpg', '64a922de7abccae293ad8.jpg', '2d96c25a99382966702915.jpg', '0fd80b355057e009b94623.jpg']
#
# 0: 640x480 1 cccd, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_1.jpg
#
# 0: 640x480 1 cccd, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_2.jpg
#
# 0: 640x480 1 cccd, 8.9ms
# Speed: 2.6ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_3.jpg
#
# 0: 640x480 2 cccds, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_4.jpg
# Lưu ảnh: output_cccd/cccd_5.jpg
#
# 0: 640x480 2 cccds, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_6.jpg
# Lưu ảnh: output_cccd/cccd_7.jpg
#
# 0: 640x480 1 cccd, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_8.jpg
#
# 0: 640x480 2 cccds, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_9.jpg
# Lưu ảnh: output_cccd/cccd_10.jpg
#
# 0: 640x480 1 cccd, 9.0ms
# Speed: 2.7ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_11.jpg
#
# 0: 640x480 1 cccd, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_12.jpg
#
# 0: 640x480 2 cccds, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_13.jpg
# Lưu ảnh: output_cccd/cccd_14.jpg
#
# 0: 640x480 2 cccds, 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_15.jpg
# Lưu ảnh: output_cccd/cccd_16.jpg
#
# 0: 640x480 1 cccd, 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_17.jpg
#
# 0: 640x480 2 cccds, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_18.jpg
# Lưu ảnh: output_cccd/cccd_19.jpg
#
# 0: 640x480 1 cccd, 9.0ms
# Speed: 2.6ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_20.jpg
#
# 0: 640x480 2 cccds, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_21.jpg
# Lưu ảnh: output_cccd/cccd_22.jpg
#
# 0: 640x480 1 cccd, 9.2ms
# Speed: 2.5ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_23.jpg
#
# 0: 640x480 2 cccds, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_24.jpg
# Lưu ảnh: output_cccd/cccd_25.jpg
#
# 0: 640x480 1 cccd, 9.0ms
# Speed: 2.2ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_26.jpg
#
# 0: 640x480 3 cccds, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_27.jpg
# Lưu ảnh: output_cccd/cccd_28.jpg
# Lưu ảnh: output_cccd/cccd_29.jpg
#
# 0: 640x480 1 cccd, 12.7ms
# Speed: 4.1ms preprocess, 12.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_30.jpg
#
# 0: 640x480 2 cccds, 14.3ms
# Speed: 2.5ms preprocess, 14.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_31.jpg
# Lưu ảnh: output_cccd/cccd_32.jpg
#
# 0: 640x480 1 cccd, 9.0ms
# Speed: 2.4ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_33.jpg
#
# 0: 640x480 1 cccd, 8.9ms
# Speed: 2.8ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_34.jpg
#
# 0: 640x480 2 cccds, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Lưu ảnh: output_cccd/cccd_35.jpg
# Lưu ảnh: output_cccd/cccd_36.jpg
# 🎉 Quá trình nhận diện & lưu ảnh hoàn tất!

# %%
import cv2
import os
import glob
def transform(img):
    #Init orb, keypoints detection on base Image
    orb = cv2.ORB_create(1000)
    kp, des = orb.detectAndCompute(baseImg, None)
    PER_MATCH = 0.25

    #Detect keypoint on img
    kp1, des1 = orb.detectAndCompute(img, None)

    #Init BF Matcher, find the matches points of two images
    bf = cv2.BFMatcher(cv2.NORM_HAMMING)
    matches = list(bf.match(des1, des))

    #Select top 30% best matcher 
    matches.sort(key=lambda x: x.distance)
    best_matches = matches[:int(len(matches)*PER_MATCH)]
    
    #Init source points and destination points for findHomography function.
    srcPoints = np.float32([kp1[m.queryIdx].pt for m in best_matches]).reshape(-1,1,2)
    dstPoints = np.float32([kp[m.trainIdx].pt for m in best_matches]).reshape(-1,1,2)


    #Find Homography of two images
    matrix_relationship, _ = cv2.findHomography(srcPoints, dstPoints,cv2.RANSAC, 5.0)

    #Transform the image to have the same structure as the base image
    img_final = cv2.warpPerspective(img, matrix_relationship, (baseW, baseH))

    return img_final

    
# Thư mục nguồn và đích
source_folder = "output_cccd1/"  # Thay bằng đường dẫn thư mục chứa ảnh gốc
destination_folder = "output_cccd_rotated/"  # Thay bằng đường dẫn thư mục đích

# Tạo thư mục đích nếu chưa có
os.makedirs(destination_folder, exist_ok=True)

image_paths = sorted(glob.glob(os.path.join(source_folder, "*.*")), key=os.path.basename)

# Duyệt qua từng ảnh
for idx, image_path in enumerate(image_paths, start=1):
    # Đọc ảnh
    img = cv2.imread(image_path)
    
    # Tạo tên file mới theo thứ tự
    new_filename = os.path.join(destination_folder, f"{idx:04d}.png")  # 0001.png, 0002.png,...
    
    # Ghi ảnh vào thư mục đích
    cv2.imwrite(new_filename, transform(img))
    print(f"Đã lưu: {new_filename}")

print("Hoàn thành xử lý ảnh!")
# Out:
# Đã lưu: output_cccd_rotated/0001.png
# Đã lưu: output_cccd_rotated/0002.png
# Đã lưu: output_cccd_rotated/0003.png
# Đã lưu: output_cccd_rotated/0004.png
# Đã lưu: output_cccd_rotated/0005.png
# Đã lưu: output_cccd_rotated/0006.png
# Đã lưu: output_cccd_rotated/0007.png
# Đã lưu: output_cccd_rotated/0008.png
# Đã lưu: output_cccd_rotated/0009.png
# Đã lưu: output_cccd_rotated/0010.png
# Đã lưu: output_cccd_rotated/0011.png
# Đã lưu: output_cccd_rotated/0012.png
# Đã lưu: output_cccd_rotated/0013.png
# Đã lưu: output_cccd_rotated/0014.png
# Đã lưu: output_cccd_rotated/0015.png
# Đã lưu: output_cccd_rotated/0016.png
# Đã lưu: output_cccd_rotated/0017.png
# Đã lưu: output_cccd_rotated/0018.png
# Đã lưu: output_cccd_rotated/0019.png
# Đã lưu: output_cccd_rotated/0020.png
# Đã lưu: output_cccd_rotated/0021.png
# Hoàn thành xử lý ảnh!

# %%
import cv2
import torch
from ultralytics import YOLO
model = YOLO("weights/detect_text_best.pt")  # Có thể thay bằng yolov8n.pt, yolov8m.pt, ...

# Đọc ảnh
image_path = "output_cccd_rotated/0003.png"
image = cv2.imread(image_path)

# Chạy model YOLO detect vật thể
results = model(image)

# Danh sách lưu thông tin vật thể
image_text_list = []

# Duyệt qua từng vật thể được phát hiện
for result in results:
    for box in result.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Lấy tọa độ (xmin, ymin, xmax, ymax)
        cropped_img_image = image[y1:y2, x1:x2]
        conf = float(box.conf[0])  # Độ tin cậy (confidence)
        cls = int(box.cls[0])  # Nhãn lớp (class ID)
        class_name = model.names[cls]  # Lấy tên lớp (vd: 'person', 'car',...)

        # Thêm vào danh sách
        image_text_list.append({
            "class": class_name,
            "bbox": cropped_img_image,
            "confidence": conf
        })

# In kết quả
for obj in image_text_list:
    print(obj)

print(f"Đã phát hiện {len(image_text_list)} vật thể!")
# Out:
# 0: 448x640 3 births, 10 names, 1 no, 9.5ms
# Speed: 2.4ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# {'class': 'name', 'bbox': array([[[157, 197, 229],
#         [156, 198, 227],
#         [154, 197, 227],
#         ...,
#         [174, 202, 249],
#         [173, 202, 247],
#         [173, 202, 247]],
#
#        [[156, 198, 228],
#         [155, 199, 228],
#         [152, 199, 228],
#         ...,
#         [173, 201, 248],
#         [172, 200, 247],
#         [173, 202, 249]],
#
#        [[158, 200, 229],
#         [157, 201, 228],
#         [151, 198, 227],
#         ...,
#         [172, 201, 248],
#         [173, 201, 248],
#         [172, 201, 248]],
#
#        ...,
#
#        [[130, 168, 195],
#         [104, 141, 164],
#         [ 79, 112, 129],
#         ...,
#         [159, 193, 241],
#         [157, 193, 242],
#         [151, 191, 240]],
#
#        [[128, 162, 189],
#         [ 97, 130, 152],
#         [ 89, 119, 134],
#         ...,
#         [159, 195, 241],
#         [161, 198, 246],
#         [147, 186, 234]],
#
#        [[137, 164, 192],
#         [103, 130, 152],
#         [ 95, 120, 136],
#         ...,
#         [ 43,  78, 124],
#         [105, 141, 187],
#         [148, 184, 232]]], dtype=uint8), 'confidence': 0.9604552984237671}
# {'class': 'name', 'bbox': array([[[150, 192, 220],
#         [150, 191, 223],
#         [144, 189, 220],
#         ...,
#         [169, 198, 246],
#         [171, 199, 246],
#         [172, 200, 247]],
#
#        [[148, 192, 220],
#         [147, 192, 222],
#         [144, 190, 221],
#         ...,
#         [167, 199, 248],
#         [168, 199, 248],
#         [172, 200, 250]],
#
#        [[147, 191, 219],
#         [147, 189, 220],
#         [147, 191, 222],
#         ...,
#         [166, 200, 249],
#         [166, 200, 249],
#         [169, 200, 249]],
#
#        ...,
#
#        [[153, 193, 219],
#         [155, 193, 220],
#         [152, 190, 216],
#         ...,
#         [ 60,  94, 135],
#         [ 29,  66, 105],
#         [ 54,  92, 131]],
#
#        [[152, 192, 219],
#         [151, 191, 219],
#         [153, 193, 221],
#         ...,
#         [ 32,  72, 114],
#         [ 63, 103, 145],
#         [111, 154, 193]],
#
#        [[151, 192, 220],
#         [150, 191, 220],
#         [152, 192, 223],
#         ...,
#         [ 41,  84, 127],
#         [105, 149, 192],
#         [123, 167, 208]]], dtype=uint8), 'confidence': 0.7414392828941345}
# {'class': 'birth', 'bbox': array([[[145, 193, 245],
#         [147, 194, 248],
#         [154, 200, 254],
#         ...,
#         [158, 196, 234],
#         [154, 193, 231],
#         [156, 198, 235]],
#
#        [[149, 199, 249],
#         [151, 202, 253],
#         [149, 199, 251],
#         ...,
#         [159, 195, 233],
#         [156, 194, 232],
#         [154, 195, 232]],
#
#        [[153, 201, 252],
#         [154, 202, 254],
#         [147, 194, 247],
#         ...,
#         [166, 199, 238],
#         [158, 195, 233],
#         [153, 192, 231]],
#
#        ...,
#
#        [[152, 196, 244],
#         [154, 197, 246],
#         [153, 198, 247],
#         ...,
#         [150, 190, 227],
#         [157, 196, 233],
#         [159, 196, 234]],
#
#        [[157, 196, 244],
#         [157, 196, 245],
#         [156, 195, 244],
#         ...,
#         [149, 189, 227],
#         [155, 194, 232],
#         [160, 199, 235]],
#
#        [[165, 199, 246],
#         [166, 199, 248],
#         [165, 198, 247],
#         ...,
#         [152, 192, 229],
#         [157, 196, 233],
#         [155, 195, 231]]], dtype=uint8), 'confidence': 0.656367301940918}
# {'class': 'name', 'bbox': array([[[132, 182, 209],
#         [133, 182, 211],
#         [134, 182, 212],
#         ...,
#         [150, 178, 194],
#         [146, 176, 194],
#         [146, 176, 195]],
#
#        [[131, 182, 210],
#         [134, 183, 213],
#         [135, 182, 214],
#         ...,
#         [144, 172, 188],
#         [143, 172, 189],
#         [143, 173, 190]],
#
#        [[130, 182, 212],
#         [133, 182, 213],
#         [135, 181, 213],
#         ...,
#         [148, 174, 190],
#         [148, 176, 192],
#         [147, 176, 194]],
#
#        ...,
#
#        [[130, 178, 207],
#         [129, 176, 207],
#         [130, 175, 208],
#         ...,
#         [137, 172, 198],
#         [140, 175, 201],
#         [139, 175, 199]],
#
#        [[134, 180, 210],
#         [133, 178, 211],
#         [132, 178, 212],
#         ...,
#         [140, 173, 199],
#         [137, 172, 197],
#         [138, 172, 196]],
#
#        [[137, 180, 213],
#         [135, 180, 213],
#         [135, 181, 215],
#         ...,
#         [139, 171, 195],
#         [139, 171, 195],
#         [139, 172, 196]]], dtype=uint8), 'confidence': 0.6438989043235779}
# {'class': 'name', 'bbox': array([[[116, 175, 204],
#         [118, 172, 201],
#         [126, 168, 197],
#         ...,
#         [142, 175, 192],
#         [140, 173, 189],
#         [139, 170, 185]],
#
#        [[120, 176, 205],
#         [119, 172, 202],
#         [126, 173, 203],
#         ...,
#         [138, 172, 188],
#         [139, 171, 187],
#         [139, 171, 186]],
#
#        [[124, 173, 202],
#         [121, 169, 200],
#         [122, 169, 201],
#         ...,
#         [139, 171, 190],
#         [141, 171, 188],
#         [143, 174, 189]],
#
#        ...,
#
#        [[135, 180, 213],
#         [134, 179, 213],
#         [135, 177, 212],
#         ...,
#         [ 61,  83, 106],
#         [ 71,  94, 116],
#         [115, 134, 159]],
#
#        [[130, 179, 210],
#         [126, 174, 206],
#         [128, 173, 207],
#         ...,
#         [ 65,  83, 105],
#         [ 78,  97, 118],
#         [121, 136, 162]],
#
#        [[129, 180, 211],
#         [126, 175, 208],
#         [127, 173, 207],
#         ...,
#         [ 56,  73,  95],
#         [ 72,  89, 110],
#         [123, 136, 162]]], dtype=uint8), 'confidence': 0.6213800311088562}
# {'class': 'no', 'bbox': array([[[156, 158, 183],
#         [150, 162, 186],
#         [149, 169, 194],
#         ...,
#         [152, 197, 234],
#         [153, 198, 232],
#         [153, 198, 232]],
#
#        [[120, 123, 151],
#         [134, 146, 175],
#         [136, 157, 186],
#         ...,
#         [152, 197, 234],
#         [154, 199, 233],
#         [154, 198, 233]],
#
#        [[145, 159, 192],
#         [154, 172, 207],
#         [153, 177, 210],
#         ...,
#         [152, 197, 234],
#         [153, 198, 232],
#         [153, 197, 233]],
#
#        ...,
#
#        [[164, 199, 245],
#         [165, 200, 246],
#         [165, 201, 246],
#         ...,
#         [155, 195, 231],
#         [159, 199, 234],
#         [156, 198, 230]],
#
#        [[165, 201, 248],
#         [166, 201, 244],
#         [165, 200, 242],
#         ...,
#         [156, 198, 233],
#         [156, 198, 232],
#         [154, 197, 229]],
#
#        [[167, 203, 250],
#         [165, 201, 243],
#         [162, 198, 238],
#         ...,
#         [156, 197, 232],
#         [156, 198, 231],
#         [155, 197, 230]]], dtype=uint8), 'confidence': 0.5490797758102417}
# {'class': 'name', 'bbox': array([[[132, 178, 209],
#         [132, 177, 210],
#         [133, 179, 209],
#         ...,
#         [145, 182, 204],
#         [144, 181, 204],
#         [144, 181, 205]],
#
#        [[136, 182, 214],
#         [135, 180, 213],
#         [136, 180, 213],
#         ...,
#         [147, 182, 204],
#         [146, 183, 205],
#         [145, 182, 206]],
#
#        [[137, 182, 215],
#         [136, 181, 215],
#         [137, 181, 213],
#         ...,
#         [141, 176, 196],
#         [139, 176, 196],
#         [137, 174, 196]],
#
#        ...,
#
#        [[133, 174, 203],
#         [144, 179, 212],
#         [138, 178, 210],
#         ...,
#         [123, 128, 149],
#         [ 98, 107, 127],
#         [119, 130, 154]],
#
#        [[130, 172, 202],
#         [142, 177, 210],
#         [135, 174, 206],
#         ...,
#         [109, 113, 138],
#         [ 80,  85, 110],
#         [ 84,  94, 121]],
#
#        [[127, 167, 199],
#         [135, 171, 203],
#         [132, 171, 200],
#         ...,
#         [113, 119, 147],
#         [110, 117, 146],
#         [139, 148, 179]]], dtype=uint8), 'confidence': 0.4308098554611206}
# {'class': 'birth', 'bbox': array([[[163, 197, 246],
#         [156, 198, 247],
#         [155, 198, 247],
#         ...,
#         [159, 193, 217],
#         [161, 198, 221],
#         [159, 195, 217]],
#
#        [[160, 198, 248],
#         [153, 197, 247],
#         [150, 195, 247],
#         ...,
#         [164, 198, 222],
#         [158, 195, 217],
#         [160, 196, 218]],
#
#        [[156, 197, 247],
#         [147, 194, 244],
#         [145, 193, 244],
#         ...,
#         [172, 204, 228],
#         [159, 194, 217],
#         [159, 195, 217]],
#
#        ...,
#
#        [[139, 192, 245],
#         [136, 192, 245],
#         [136, 190, 246],
#         ...,
#         [152, 170, 185],
#         [159, 181, 197],
#         [165, 191, 211]],
#
#        [[137, 192, 247],
#         [135, 190, 246],
#         [136, 190, 247],
#         ...,
#         [157, 172, 184],
#         [166, 184, 200],
#         [167, 192, 209]],
#
#        [[134, 192, 248],
#         [135, 191, 247],
#         [135, 190, 247],
#         ...,
#         [172, 183, 194],
#         [176, 190, 205],
#         [173, 194, 210]]], dtype=uint8), 'confidence': 0.3865289092063904}
# {'class': 'name', 'bbox': array([[[139, 180, 212],
#         [140, 180, 213],
#         [138, 181, 214],
#         ...,
#         [141, 177, 221],
#         [142, 175, 222],
#         [142, 174, 225]],
#
#        [[139, 179, 211],
#         [142, 179, 212],
#         [140, 177, 211],
#         ...,
#         [142, 175, 221],
#         [146, 176, 223],
#         [149, 180, 227]],
#
#        [[140, 178, 209],
#         [144, 178, 211],
#         [141, 174, 209],
#         ...,
#         [143, 177, 226],
#         [148, 182, 232],
#         [150, 185, 235]],
#
#        ...,
#
#        [[111, 170, 199],
#         [116, 168, 199],
#         [123, 172, 204],
#         ...,
#         [131, 179, 227],
#         [128, 178, 225],
#         [129, 176, 225]],
#
#        [[112, 173, 202],
#         [115, 169, 200],
#         [120, 171, 203],
#         ...,
#         [123, 179, 228],
#         [131, 187, 236],
#         [129, 182, 234]],
#
#        [[115, 171, 200],
#         [117, 172, 202],
#         [119, 170, 202],
#         ...,
#         [118, 178, 228],
#         [115, 176, 227],
#         [112, 169, 222]]], dtype=uint8), 'confidence': 0.38064640760421753}
# {'class': 'name', 'bbox': array([[[137, 185, 214],
#         [138, 184, 215],
#         [139, 180, 212],
#         ...,
#         [140, 189, 235],
#         [139, 186, 230],
#         [144, 191, 235]],
#
#        [[135, 182, 211],
#         [137, 182, 213],
#         [136, 177, 209],
#         ...,
#         [146, 193, 240],
#         [131, 175, 220],
#         [119, 162, 206]],
#
#        [[136, 179, 208],
#         [141, 182, 211],
#         [142, 179, 209],
#         ...,
#         [149, 192, 237],
#         [117, 156, 200],
#         [ 89, 127, 170]],
#
#        ...,
#
#        [[129, 179, 207],
#         [131, 182, 210],
#         [134, 183, 213],
#         ...,
#         [154, 169, 181],
#         [150, 166, 178],
#         [150, 167, 177]],
#
#        [[130, 180, 210],
#         [130, 182, 212],
#         [133, 182, 213],
#         ...,
#         [154, 168, 180],
#         [151, 166, 178],
#         [148, 166, 176]],
#
#        [[133, 182, 210],
#         [131, 181, 211],
#         [132, 181, 211],
#         ...,
#         [153, 167, 179],
#         [149, 165, 175],
#         [147, 166, 173]]], dtype=uint8), 'confidence': 0.351550817489624}
# {'class': 'name', 'bbox': array([[[142, 183, 208],
#         [142, 183, 208],
#         [139, 182, 209],
#         ...,
#         [166, 183, 192],
#         [164, 183, 191],
#         [157, 176, 184]],
#
#        [[139, 180, 205],
#         [140, 181, 206],
#         [138, 181, 208],
#         ...,
#         [157, 171, 180],
#         [163, 178, 187],
#         [167, 184, 193]],
#
#        [[138, 179, 204],
#         [139, 180, 205],
#         [137, 180, 207],
#         ...,
#         [157, 168, 176],
#         [163, 174, 182],
#         [159, 172, 180]],
#
#        ...,
#
#        [[144, 184, 213],
#         [143, 184, 213],
#         [138, 183, 211],
#         ...,
#         [157, 178, 181],
#         [160, 179, 183],
#         [154, 170, 176]],
#
#        [[145, 183, 213],
#         [143, 183, 212],
#         [138, 183, 211],
#         ...,
#         [162, 182, 188],
#         [163, 182, 188],
#         [155, 174, 180]],
#
#        [[145, 184, 213],
#         [143, 184, 214],
#         [139, 182, 214],
#         ...,
#         [169, 191, 197],
#         [162, 183, 190],
#         [154, 174, 182]]], dtype=uint8), 'confidence': 0.32211852073669434}
# {'class': 'name', 'bbox': array([[[159, 198, 226],
#         [163, 202, 230],
#         [161, 201, 230],
#         ...,
#         [159, 188, 234],
#         [121, 145, 191],
#         [ 71,  96, 140]],
#
#        [[156, 197, 226],
#         [158, 199, 227],
#         [156, 198, 226],
#         ...,
#         [154, 183, 227],
#         [109, 133, 178],
#         [ 79, 104, 147]],
#
#        [[154, 196, 225],
#         [153, 196, 225],
#         [152, 196, 225],
#         ...,
#         [146, 175, 219],
#         [106, 131, 175],
#         [ 74,  99, 141]],
#
#        ...,
#
#        [[141, 182, 209],
#         [132, 166, 196],
#         [107, 142, 167],
#         ...,
#         [168, 199, 248],
#         [167, 199, 247],
#         [164, 199, 245]],
#
#        [[140, 182, 208],
#         [128, 165, 193],
#         [101, 140, 164],
#         ...,
#         [166, 198, 247],
#         [167, 199, 247],
#         [166, 200, 246]],
#
#        [[140, 181, 207],
#         [130, 168, 195],
#         [104, 141, 164],
#         ...,
#         [165, 197, 246],
#         [167, 199, 247],
#         [169, 201, 247]]], dtype=uint8), 'confidence': 0.28170421719551086}
# {'class': 'birth', 'bbox': array([[[118, 182, 233],
#         [111, 181, 232],
#         [113, 181, 235],
#         ...,
#         [167, 191, 213],
#         [166, 190, 212],
#         [167, 191, 212]],
#
#        [[118, 184, 233],
#         [111, 182, 232],
#         [109, 179, 230],
#         ...,
#         [162, 186, 205],
#         [159, 184, 203],
#         [162, 185, 204]],
#
#        [[109, 170, 218],
#         [113, 179, 228],
#         [111, 178, 229],
#         ...,
#         [160, 183, 200],
#         [158, 180, 199],
#         [155, 176, 193]],
#
#        ...,
#
#        [[122, 171, 227],
#         [123, 171, 227],
#         [121, 169, 222],
#         ...,
#         [127, 160, 172],
#         [136, 169, 182],
#         [134, 167, 183]],
#
#        [[126, 169, 222],
#         [137, 178, 231],
#         [132, 173, 225],
#         ...,
#         [137, 171, 184],
#         [134, 168, 181],
#         [136, 169, 183]],
#
#        [[137, 172, 221],
#         [135, 170, 220],
#         [117, 150, 200],
#         ...,
#         [132, 166, 179],
#         [129, 162, 175],
#         [137, 169, 182]]], dtype=uint8), 'confidence': 0.28031787276268005}
# {'class': 'name', 'bbox': array([[[135, 183, 211],
#         [131, 181, 209],
#         [131, 178, 206],
#         ...,
#         [129, 181, 232],
#         [126, 177, 228],
#         [120, 173, 220]],
#
#        [[133, 181, 209],
#         [130, 177, 208],
#         [128, 175, 204],
#         ...,
#         [130, 177, 219],
#         [125, 171, 211],
#         [117, 163, 202]],
#
#        [[131, 179, 209],
#         [130, 176, 208],
#         [128, 175, 205],
#         ...,
#         [130, 173, 206],
#         [126, 166, 198],
#         [124, 162, 193]],
#
#        ...,
#
#        [[124, 171, 201],
#         [128, 173, 205],
#         [131, 179, 210],
#         ...,
#         [ 36,  79, 120],
#         [ 76, 120, 156],
#         [118, 163, 194]],
#
#        [[122, 169, 197],
#         [126, 172, 203],
#         [127, 177, 208],
#         ...,
#         [ 41,  81, 115],
#         [ 71, 111, 140],
#         [102, 140, 167]],
#
#        [[120, 168, 196],
#         [124, 170, 201],
#         [127, 176, 207],
#         ...,
#         [ 24,  61,  89],
#         [ 71, 105, 130],
#         [105, 133, 158]]], dtype=uint8), 'confidence': 0.26156488060951233}
# Đã phát hiện 14 vật thể!

# %% [markdown]
# # OCR texts

# %%
preprocesing_image_text_list = []
def preprocessing_image(img):
    #Resize image 
    #img = cv2.resize(img, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_CUBIC)

    #convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.multiply(gray, 1.5)
    
    #blur remove noise
    blured1 = cv2.medianBlur(gray,3)
    blured2 = cv2.medianBlur(gray,51)
    divided = np.ma.divide(blured1, blured2).data
    normed = np.uint8(255*divided/divided.max())
    
    
    #Threshold image
    th, threshed = cv2.threshold(normed, 0, 255, cv2.THRESH_OTSU + cv2.THRESH_BINARY)
    
    
    return threshed
for img in image_text_list:
    pre_img = preprocessing_image(img["bbox"])
    preprocesing_image_text_list.append(pre_img)
    display_img(pre_img)

# %%
from vietocr.tool.predictor import Predictor
from vietocr.tool.config import Cfg
import os
from PIL import Image
import numpy as np

YOLO_MODEL_PATH = os.getenv("YOLO_MODEL_PATH", "ocr/best.pt")
CONFIDENCE_THRESHOLD =  0.25
OCR_CONFIG_NAME = "vgg_transformer"
OCR_DEVICE = "cpu"

def load_ocr_model() -> Predictor:
    """Load VietOCR model."""
    config = Cfg.load_config_from_name(OCR_CONFIG_NAME)
    config['device'] = OCR_DEVICE  # Use GPU if available
    return Predictor(config)

ocr_model = load_ocr_model()

# Thực hiện OCR
for text_img in preprocesing_image_text_list:
    if isinstance(text_img, np.ndarray):
        text_img = Image.fromarray(text_img)  # Chuyển numpy -> PIL
    text = ocr_model.predict(text_img)
    print("Kết quả OCR:", text)
# Out:
# /home/anodi108/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Model weight /tmp/vgg_transformer.pth exsits. Ignore download!
# Kết quả OCR: PHẠM ĐĂNG ĐỒNG
# Kết quả OCR: Ngày sinh là 4 - 1 mm.
# Kết quả OCR: 030203010190
# Kết quả OCR: Que quan kmetingn
# Kết quả OCR: converters
# Kết quả OCR: 030203010190
# Kết quả OCR: An Phương Thanh Hà
# Kết quả OCR: 0082003
# Kết quả OCR: Mo4 trường trú 1 - Xa x muân co
# Kết quả OCR: Gia thị xe Nam Quốc Qcr
# Kết quả OCR: Com minh xi Nam Quốc OriNas
# Kết quả OCR: PHẠM ĐẢNG ĐÓ
# Kết quả OCR: Thanh Hà, Hà Dương
# Kết quả OCR: 03101001001001
